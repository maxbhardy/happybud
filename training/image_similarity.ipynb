# %%
import torch
import torchvision
import torchvision.transforms.v2 as transforms_v2
import PIL

# %%
# Load a pre-trained ResNet model
model = torchvision.models.resnet18(weights="IMAGENET1K_V1")

# Remove the final layer for feature extraction
embedding_model = torch.nn.Sequential(*list(model.children())[:-1])
embedding_model.eval()  # Set model to evaluation mode
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (6): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (7): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
# Embedding pipeline
transformations = [
    # Conversion to float32 image tensor
    transforms_v2.ToImage(),
    transforms_v2.ToDtype(torch.float32, scale=True),
    transforms_v2.Resize((224, 224), antialias=True),
    # Normalization for ViT, valeurs de ImageNet1K
    transforms_v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
]

pipeline = transforms_v2.Compose(transformations)

# %%
# Load and transform the image
image = PIL.Image.open("data/cucumber_leaf_disease_dataset/cucumber_Leaf_Disease/train/Downy_mildew/IMG_0009.JPG")
image = pipeline(image).unsqueeze(0)  # Add batch dimension

# %%
with torch.no_grad():
    embedding = embedding_model(image).flatten()

# %%
image2 = PIL.Image.open("data/cucumber_leaf_disease_dataset/cucumber_Leaf_Disease/train/Downy_mildew/IMG_0010.JPG")
image2 = pipeline(image2).unsqueeze(0)  # Add batch dimension
embedding2 = embedding_model(image2).flatten()

# %%
def encode_image(file):
    image = PIL.Image.open(file)#.unsqeeze(0)
    image = pipeline(image).unsqueeze(0)
    embedding = embedding_model(image).flatten()

    return embedding

# %%
def cosine_similarity(embedding1, embedding2):
    return torch.nn.functional.cosine_similarity(
        embedding1.unsqueeze(0), embedding2.unsqueeze(0)
    )

# %%
cosine_similarity(embedding, embedding2)
# Out:
# tensor([0.9460], grad_fn=<SumBackward1>)

# %%
image3 = PIL.Image.open("data/cucumber_leaf_disease_dataset/cucumber_Leaf_Disease/train/Downy_mildew/IMG_0012.JPG")
image3 = pipeline(image3).unsqueeze(0)  # Add batch dimension
embedding3 = embedding_model(image3).flatten()

# %%
cosine_similarity(embedding, embedding3)
# Out:
# tensor([0.8253], grad_fn=<SumBackward1>)

# %%
import pathlib

# %%
path = pathlib.Path("data/cucumber_leaf_disease_dataset/cucumber_Leaf_Disease/train/Downy_mildew/")

for i, file1 in enumerate(path.iterdir()):
    image1 = encode_image(file1)

    for j, file2 in enumerate(path.iterdir()):
        image2 = encode_image(file2)
        
        print(i, j, cosine_similarity(image1, image2))
# Out:
# 0 0 tensor([1.], grad_fn=<SumBackward1>)
# 0 1 tensor([0.9460], grad_fn=<SumBackward1>)
# 0 2 tensor([0.9263], grad_fn=<SumBackward1>)
# 0 3 tensor([0.8253], grad_fn=<SumBackward1>)
# 0 4 tensor([0.8110], grad_fn=<SumBackward1>)
# 0 5 tensor([0.8411], grad_fn=<SumBackward1>)
# 0 6 tensor([0.8825], grad_fn=<SumBackward1>)
# 0 7 tensor([0.8724], grad_fn=<SumBackward1>)
# 0 8 tensor([0.8591], grad_fn=<SumBackward1>)
# 0 9 tensor([0.8435], grad_fn=<SumBackward1>)
# 0 10 tensor([0.8714], grad_fn=<SumBackward1>)
# 0 11 tensor([0.8407], grad_fn=<SumBackward1>)
# 0 12 tensor([0.8156], grad_fn=<SumBackward1>)
# 0 13 tensor([0.8448], grad_fn=<SumBackward1>)
# 0 14 tensor([0.8329], grad_fn=<SumBackward1>)
# 0 15 tensor([0.8172], grad_fn=<SumBackward1>)
# 0 16 tensor([0.8013], grad_fn=<SumBackward1>)
# 0 17 tensor([0.8029], grad_fn=<SumBackward1>)
# 0 18 tensor([0.7993], grad_fn=<SumBackward1>)
# 0 19 tensor([0.7788], grad_fn=<SumBackward1>)
# 0 20 tensor([0.8412], grad_fn=<SumBackward1>)
# 0 21 tensor([0.8663], grad_fn=<SumBackward1>)
# 0 22 tensor([0.8780], grad_fn=<SumBackward1>)
# 0 23 tensor([0.8789], grad_fn=<SumBackward1>)
# 0 24 tensor([0.8599], grad_fn=<SumBackward1>)
# 0 25 tensor([0.8487], grad_fn=<SumBackward1>)
# 0 26 tensor([0.8465], grad_fn=<SumBackward1>)
# 0 27 tensor([0.8422], grad_fn=<SumBackward1>)
# 0 28 tensor([0.8744], grad_fn=<SumBackward1>)
# 0 29 tensor([0.8527], grad_fn=<SumBackward1>)
# 0 30 tensor([0.8313], grad_fn=<SumBackward1>)
# 0 31 tensor([0.7908], grad_fn=<SumBackward1>)
# 0 32 tensor([0.8163], grad_fn=<SumBackward1>)
# 0 33 tensor([0.8213], grad_fn=<SumBackward1>)
# 0 34 tensor([0.8218], grad_fn=<SumBackward1>)
# 0 35 tensor([0.8456], grad_fn=<SumBackward1>)
# 0 36 tensor([0.8515], grad_fn=<SumBackward1>)
# 0 37 tensor([0.8373], grad_fn=<SumBackward1>)
# 0 38 tensor([0.8191], grad_fn=<SumBackward1>)
# 0 39 tensor([0.8174], grad_fn=<SumBackward1>)
# 0 40 tensor([0.8348], grad_fn=<SumBackward1>)
# 0 41 tensor([0.8353], grad_fn=<SumBackward1>)
# 0 42 tensor([0.8094], grad_fn=<SumBackward1>)
# 0 43 tensor([0.8224], grad_fn=<SumBackward1>)
# 0 44 tensor([0.8747], grad_fn=<SumBackward1>)
# 0 45 tensor([0.8892], grad_fn=<SumBackward1>)
# 0 46 tensor([0.8657], grad_fn=<SumBackward1>)
# 0 47 tensor([0.8832], grad_fn=<SumBackward1>)
# 0 48 tensor([0.8573], grad_fn=<SumBackward1>)
# 0 49 tensor([0.8620], grad_fn=<SumBackward1>)
# 0 50 tensor([0.8311], grad_fn=<SumBackward1>)
# 0 51 tensor([0.8413], grad_fn=<SumBackward1>)
# 0 52 tensor([0.8361], grad_fn=<SumBackward1>)
# 0 53 tensor([0.8199], grad_fn=<SumBackward1>)
# 0 54 tensor([0.8811], grad_fn=<SumBackward1>)
# 0 55 tensor([0.8593], grad_fn=<SumBackward1>)
# 0 56 tensor([0.8526], grad_fn=<SumBackward1>)
# 0 57 tensor([0.8345], grad_fn=<SumBackward1>)
# 0 58 tensor([0.8531], grad_fn=<SumBackward1>)
# 0 59 tensor([0.8620], grad_fn=<SumBackward1>)
# 0 60 tensor([0.8807], grad_fn=<SumBackward1>)
# 0 61 tensor([0.8657], grad_fn=<SumBackward1>)
# 0 62 tensor([0.8808], grad_fn=<SumBackward1>)
# 0 63 tensor([0.8500], grad_fn=<SumBackward1>)
# 0 64 tensor([0.8491], grad_fn=<SumBackward1>)
# 0 65 tensor([0.8755], grad_fn=<SumBackward1>)
# 0 66 tensor([0.8410], grad_fn=<SumBackward1>)
# 0 67 tensor([0.8365], grad_fn=<SumBackward1>)
# 0 68 tensor([0.8719], grad_fn=<SumBackward1>)
# 0 69 tensor([0.8352], grad_fn=<SumBackward1>)
# 0 70 tensor([0.8528], grad_fn=<SumBackward1>)
# 0 71 tensor([0.8676], grad_fn=<SumBackward1>)
# 0 72 tensor([0.8364], grad_fn=<SumBackward1>)
# 0 73 tensor([0.8400], grad_fn=<SumBackward1>)
# 0 74 tensor([0.8695], grad_fn=<SumBackward1>)
# 0 75 tensor([0.8809], grad_fn=<SumBackward1>)
# 0 76 tensor([0.8642], grad_fn=<SumBackward1>)
# 0 77 tensor([0.8184], grad_fn=<SumBackward1>)
# 0 78 tensor([0.8394], grad_fn=<SumBackward1>)
# 0 79 tensor([0.8234], grad_fn=<SumBackward1>)
# 0 80 tensor([0.8767], grad_fn=<SumBackward1>)
# 0 81 tensor([0.8919], grad_fn=<SumBackward1>)
# 0 82 tensor([0.8528], grad_fn=<SumBackward1>)
# 0 83 tensor([0.8627], grad_fn=<SumBackward1>)
# 0 84 tensor([0.8412], grad_fn=<SumBackward1>)
# 0 85 tensor([0.8601], grad_fn=<SumBackward1>)
# 0 86 tensor([0.8306], grad_fn=<SumBackward1>)
# 0 87 tensor([0.8334], grad_fn=<SumBackward1>)
# 0 88 tensor([0.8289], grad_fn=<SumBackward1>)
# 0 89 tensor([0.8375], grad_fn=<SumBackward1>)
# 0 90 tensor([0.8348], grad_fn=<SumBackward1>)
# 0 91 tensor([0.8420], grad_fn=<SumBackward1>)
# 0 92 tensor([0.8250], grad_fn=<SumBackward1>)
# 0 93 tensor([0.7888], grad_fn=<SumBackward1>)
# 0 94 tensor([0.7945], grad_fn=<SumBackward1>)
# 0 95 tensor([0.8308], grad_fn=<SumBackward1>)
# 0 96 tensor([0.8036], grad_fn=<SumBackward1>)
# 0 97 tensor([0.8205], grad_fn=<SumBackward1>)
# 0 98 tensor([0.8406], grad_fn=<SumBackward1>)
# 0 99 tensor([0.8218], grad_fn=<SumBackward1>)
# 0 100 tensor([0.8547], grad_fn=<SumBackward1>)
# 0 101 tensor([0.8587], grad_fn=<SumBackward1>)
# 0 102 tensor([0.8611], grad_fn=<SumBackward1>)
# 0 103 tensor([0.8732], grad_fn=<SumBackward1>)
# 0 104 tensor([0.8360], grad_fn=<SumBackward1>)
# 0 105 tensor([0.8322], grad_fn=<SumBackward1>)
# 0 106 tensor([0.8348], grad_fn=<SumBackward1>)
# 0 107 tensor([0.8642], grad_fn=<SumBackward1>)
# 0 108 tensor([0.8311], grad_fn=<SumBackward1>)
# 0 109 tensor([0.7891], grad_fn=<SumBackward1>)
# 0 110 tensor([0.8370], grad_fn=<SumBackward1>)
# 0 111 tensor([0.8393], grad_fn=<SumBackward1>)
# 0 112 tensor([0.8291], grad_fn=<SumBackward1>)
# 0 113 tensor([0.8810], grad_fn=<SumBackward1>)
# 0 114 tensor([0.8746], grad_fn=<SumBackward1>)
# 0 115 tensor([0.8689], grad_fn=<SumBackward1>)
# 0 116 tensor([0.8761], grad_fn=<SumBackward1>)
# 0 117 tensor([0.8274], grad_fn=<SumBackward1>)
# 0 118 tensor([0.8560], grad_fn=<SumBackward1>)
# 0 119 tensor([0.8752], grad_fn=<SumBackward1>)
# 0 120 tensor([0.8279], grad_fn=<SumBackward1>)
# 0 121 tensor([0.8260], grad_fn=<SumBackward1>)
# 0 122 tensor([0.8605], grad_fn=<SumBackward1>)
# 0 123 tensor([0.8552], grad_fn=<SumBackward1>)
# 0 124 tensor([0.8059], grad_fn=<SumBackward1>)
# 0 125 tensor([0.8166], grad_fn=<SumBackward1>)
# 0 126 tensor([0.8332], grad_fn=<SumBackward1>)
# 0 127 tensor([0.8292], grad_fn=<SumBackward1>)
# 0 128 tensor([0.8220], grad_fn=<SumBackward1>)
# 0 129 tensor([0.8964], grad_fn=<SumBackward1>)
# 0 130 tensor([0.9123], grad_fn=<SumBackward1>)
# 0 131 tensor([0.8851], grad_fn=<SumBackward1>)
# 0 132 tensor([0.8778], grad_fn=<SumBackward1>)
# 0 133 tensor([0.8356], grad_fn=<SumBackward1>)
# 0 134 tensor([0.8490], grad_fn=<SumBackward1>)
# 0 135 tensor([0.8604], grad_fn=<SumBackward1>)
# 0 136 tensor([0.8497], grad_fn=<SumBackward1>)
# 0 137 tensor([0.8377], grad_fn=<SumBackward1>)
# 0 138 tensor([0.8254], grad_fn=<SumBackward1>)
# 0 139 tensor([0.8501], grad_fn=<SumBackward1>)
# 0 140 tensor([0.8646], grad_fn=<SumBackward1>)
# 0 141 tensor([0.8724], grad_fn=<SumBackward1>)
# 0 142 tensor([0.8893], grad_fn=<SumBackward1>)
# 0 143 tensor([0.8935], grad_fn=<SumBackward1>)
# 0 144 tensor([0.8984], grad_fn=<SumBackward1>)
# 0 145 tensor([0.8527], grad_fn=<SumBackward1>)
# 0 146 tensor([0.8621], grad_fn=<SumBackward1>)
# 0 147 tensor([0.8630], grad_fn=<SumBackward1>)
# 0 148 tensor([0.8643], grad_fn=<SumBackward1>)
# 0 149 tensor([0.8449], grad_fn=<SumBackward1>)
# 0 150 tensor([0.8436], grad_fn=<SumBackward1>)
# 0 151 tensor([0.8330], grad_fn=<SumBackward1>)
# 0 152 tensor([0.8468], grad_fn=<SumBackward1>)
# 0 153 tensor([0.8146], grad_fn=<SumBackward1>)
# 0 154 tensor([0.8169], grad_fn=<SumBackward1>)
# 0 155 tensor([0.8318], grad_fn=<SumBackward1>)
# 0 156 tensor([0.8129], grad_fn=<SumBackward1>)
# 0 157 tensor([0.8404], grad_fn=<SumBackward1>)
# 0 158 tensor([0.8956], grad_fn=<SumBackward1>)
# 0 159 tensor([0.8534], grad_fn=<SumBackward1>)
# 0 160 tensor([0.8868], grad_fn=<SumBackward1>)
# 0 161 tensor([0.8864], grad_fn=<SumBackward1>)
# 0 162 tensor([0.8623], grad_fn=<SumBackward1>)
# 0 163 tensor([0.8318], grad_fn=<SumBackward1>)
# 0 164 tensor([0.8166], grad_fn=<SumBackward1>)
# 0 165 tensor([0.8349], grad_fn=<SumBackward1>)
# 0 166 tensor([0.8306], grad_fn=<SumBackward1>)
# 0 167 tensor([0.8292], grad_fn=<SumBackward1>)
# 0 168 tensor([0.8024], grad_fn=<SumBackward1>)
# 0 169 tensor([0.8249], grad_fn=<SumBackward1>)
# 0 170 tensor([0.8209], grad_fn=<SumBackward1>)
# 0 171 tensor([0.8558], grad_fn=<SumBackward1>)
# 0 172 tensor([0.8483], grad_fn=<SumBackward1>)
# 0 173 tensor([0.8134], grad_fn=<SumBackward1>)
# 0 174 tensor([0.8118], grad_fn=<SumBackward1>)
# 0 175 tensor([0.8250], grad_fn=<SumBackward1>)
# 0 176 tensor([0.8122], grad_fn=<SumBackward1>)
# 0 177 tensor([0.8476], grad_fn=<SumBackward1>)
# 0 178 tensor([0.8319], grad_fn=<SumBackward1>)
# 0 179 tensor([0.8362], grad_fn=<SumBackward1>)
# 0 180 tensor([0.8351], grad_fn=<SumBackward1>)
# 0 181 tensor([0.8477], grad_fn=<SumBackward1>)
# 0 182 tensor([0.8212], grad_fn=<SumBackward1>)
# 0 183 tensor([0.7957], grad_fn=<SumBackward1>)
# 0 184 tensor([0.7751], grad_fn=<SumBackward1>)
# 0 185 tensor([0.8221], grad_fn=<SumBackward1>)
# 0 186 tensor([0.8112], grad_fn=<SumBackward1>)
# 0 187 tensor([0.7927], grad_fn=<SumBackward1>)
# 0 188 tensor([0.8313], grad_fn=<SumBackward1>)
# 0 189 tensor([0.8621], grad_fn=<SumBackward1>)
# 0 190 tensor([0.8620], grad_fn=<SumBackward1>)
# 0 191 tensor([0.8849], grad_fn=<SumBackward1>)
# 0 192 tensor([0.8864], grad_fn=<SumBackward1>)
# 0 193 tensor([0.8524], grad_fn=<SumBackward1>)
# 0 194 tensor([0.8712], grad_fn=<SumBackward1>)
# 0 195 tensor([0.8281], grad_fn=<SumBackward1>)
# 0 196 tensor([0.8131], grad_fn=<SumBackward1>)
# 0 197 tensor([0.8286], grad_fn=<SumBackward1>)
# 0 198 tensor([0.8174], grad_fn=<SumBackward1>)
# 0 199 tensor([0.8191], grad_fn=<SumBackward1>)
# 0 200 tensor([0.7925], grad_fn=<SumBackward1>)
# 0 201 tensor([0.7982], grad_fn=<SumBackward1>)
# 0 202 tensor([0.7742], grad_fn=<SumBackward1>)
# 0 203 tensor([0.7990], grad_fn=<SumBackward1>)
# 0 204 tensor([0.7940], grad_fn=<SumBackward1>)
# 0 205 tensor([0.7976], grad_fn=<SumBackward1>)
# 0 206 tensor([0.7873], grad_fn=<SumBackward1>)
# 0 207 tensor([0.8173], grad_fn=<SumBackward1>)
# 0 208 tensor([0.8549], grad_fn=<SumBackward1>)
# 0 209 tensor([0.8465], grad_fn=<SumBackward1>)
# 0 210 tensor([0.8654], grad_fn=<SumBackward1>)
# 0 211 tensor([0.8806], grad_fn=<SumBackward1>)
# 0 212 tensor([0.8876], grad_fn=<SumBackward1>)
# 0 213 tensor([0.8796], grad_fn=<SumBackward1>)
# 0 214 tensor([0.8556], grad_fn=<SumBackward1>)
# 0 215 tensor([0.8136], grad_fn=<SumBackward1>)
# 0 216 tensor([0.8185], grad_fn=<SumBackward1>)
# 0 217 tensor([0.8026], grad_fn=<SumBackward1>)
# 0 218 tensor([0.8042], grad_fn=<SumBackward1>)
# 0 219 tensor([0.8286], grad_fn=<SumBackward1>)
# 0 220 tensor([0.8231], grad_fn=<SumBackward1>)
# 0 221 tensor([0.8416], grad_fn=<SumBackward1>)
# 0 222 tensor([0.8350], grad_fn=<SumBackward1>)
# 0 223 tensor([0.8758], grad_fn=<SumBackward1>)
# 0 224 tensor([0.8611], grad_fn=<SumBackward1>)
# 0 225 tensor([0.8813], grad_fn=<SumBackward1>)
# 0 226 tensor([0.8750], grad_fn=<SumBackward1>)
# 0 227 tensor([0.8194], grad_fn=<SumBackward1>)
# 0 228 tensor([0.8237], grad_fn=<SumBackward1>)
# 0 229 tensor([0.8049], grad_fn=<SumBackward1>)
# 0 230 tensor([0.8136], grad_fn=<SumBackward1>)
# 0 231 tensor([0.7978], grad_fn=<SumBackward1>)
# 0 232 tensor([0.8271], grad_fn=<SumBackward1>)
# 0 233 tensor([0.8370], grad_fn=<SumBackward1>)
# 0 234 tensor([0.8599], grad_fn=<SumBackward1>)
# 0 235 tensor([0.8654], grad_fn=<SumBackward1>)
# 0 236 tensor([0.8390], grad_fn=<SumBackward1>)
# 0 237 tensor([0.8663], grad_fn=<SumBackward1>)
# 0 238 tensor([0.8597], grad_fn=<SumBackward1>)
# 0 239 tensor([0.8421], grad_fn=<SumBackward1>)
# 0 240 tensor([0.8367], grad_fn=<SumBackward1>)
# 0 241 tensor([0.8150], grad_fn=<SumBackward1>)
# 0 242 tensor([0.8173], grad_fn=<SumBackward1>)
# 0 243 tensor([0.8539], grad_fn=<SumBackward1>)
# 0 244 tensor([0.8481], grad_fn=<SumBackward1>)
# 0 245 tensor([0.8340], grad_fn=<SumBackward1>)
# 0 246 tensor([0.8478], grad_fn=<SumBackward1>)
# 0 247 tensor([0.8568], grad_fn=<SumBackward1>)
# 0 248 tensor([0.8837], grad_fn=<SumBackward1>)
# 0 249 tensor([0.8745], grad_fn=<SumBackward1>)
# 0 250 tensor([0.8351], grad_fn=<SumBackward1>)
# 0 251 tensor([0.8524], grad_fn=<SumBackward1>)
# 0 252 tensor([0.8862], grad_fn=<SumBackward1>)
# 0 253 tensor([0.8902], grad_fn=<SumBackward1>)
# 0 254 tensor([0.9125], grad_fn=<SumBackward1>)
# 0 255 tensor([0.8749], grad_fn=<SumBackward1>)
# 0 256 tensor([0.8486], grad_fn=<SumBackward1>)
# 0 257 tensor([0.8572], grad_fn=<SumBackward1>)
# 0 258 tensor([0.8860], grad_fn=<SumBackward1>)
# 0 259 tensor([0.8752], grad_fn=<SumBackward1>)
# 0 260 tensor([0.9180], grad_fn=<SumBackward1>)
# 0 261 tensor([0.8834], grad_fn=<SumBackward1>)
# 0 262 tensor([0.9198], grad_fn=<SumBackward1>)
# 0 263 tensor([0.9130], grad_fn=<SumBackward1>)
# 0 264 tensor([0.9028], grad_fn=<SumBackward1>)
# 0 265 tensor([0.8644], grad_fn=<SumBackward1>)
# 0 266 tensor([0.8743], grad_fn=<SumBackward1>)
# 0 267 tensor([0.8746], grad_fn=<SumBackward1>)
# 0 268 tensor([0.8690], grad_fn=<SumBackward1>)
# 0 269 tensor([0.8718], grad_fn=<SumBackward1>)
# 0 270 tensor([0.9153], grad_fn=<SumBackward1>)
# 0 271 tensor([0.9110], grad_fn=<SumBackward1>)
# 0 272 tensor([0.9013], grad_fn=<SumBackward1>)
# 0 273 tensor([0.9056], grad_fn=<SumBackward1>)
# 0 274 tensor([0.8706], grad_fn=<SumBackward1>)
# 0 275 tensor([0.8740], grad_fn=<SumBackward1>)
# 0 276 tensor([0.8720], grad_fn=<SumBackward1>)
# 0 277 tensor([0.8567], grad_fn=<SumBackward1>)
# 0 278 tensor([0.8553], grad_fn=<SumBackward1>)
# 0 279 tensor([0.8476], grad_fn=<SumBackward1>)
# 0 280 tensor([0.8972], grad_fn=<SumBackward1>)
# 0 281 tensor([0.8832], grad_fn=<SumBackward1>)
# 0 282 tensor([0.8660], grad_fn=<SumBackward1>)
# 0 283 tensor([0.8569], grad_fn=<SumBackward1>)
# 0 284 tensor([0.8753], grad_fn=<SumBackward1>)
# 0 285 tensor([0.8689], grad_fn=<SumBackward1>)
# 0 286 tensor([0.8811], grad_fn=<SumBackward1>)
# 0 287 tensor([0.8242], grad_fn=<SumBackward1>)
# 0 288 tensor([0.8189], grad_fn=<SumBackward1>)
# 0 289 tensor([0.8433], grad_fn=<SumBackward1>)
# 0 290 tensor([0.8462], grad_fn=<SumBackward1>)
# 0 291 tensor([0.8193], grad_fn=<SumBackward1>)
# 0 292 tensor([0.8436], grad_fn=<SumBackward1>)
# 0 293 tensor([0.8539], grad_fn=<SumBackward1>)
# 0 294 tensor([0.8320], grad_fn=<SumBackward1>)
# 0 295 tensor([0.8287], grad_fn=<SumBackward1>)
# 0 296 tensor([0.8633], grad_fn=<SumBackward1>)
# 0 297 tensor([0.8427], grad_fn=<SumBackward1>)
# 0 298 tensor([0.8435], grad_fn=<SumBackward1>)
# 0 299 tensor([0.7886], grad_fn=<SumBackward1>)
# 0 300 tensor([0.8151], grad_fn=<SumBackward1>)
# 0 301 tensor([0.8069], grad_fn=<SumBackward1>)
# 0 302 tensor([0.8316], grad_fn=<SumBackward1>)
# 0 303 tensor([0.8291], grad_fn=<SumBackward1>)
# 0 304 tensor([0.8482], grad_fn=<SumBackward1>)
# 0 305 tensor([0.9093], grad_fn=<SumBackward1>)
# 0 306 tensor([0.9179], grad_fn=<SumBackward1>)
# 0 307 tensor([0.8867], grad_fn=<SumBackward1>)
# 0 308 tensor([0.8438], grad_fn=<SumBackward1>)
# 0 309 tensor([0.8618], grad_fn=<SumBackward1>)
# 0 310 tensor([0.8484], grad_fn=<SumBackward1>)
# 0 311 tensor([0.8658], grad_fn=<SumBackward1>)
# 0 312 tensor([0.8215], grad_fn=<SumBackward1>)
# 0 313 tensor([0.8412], grad_fn=<SumBackward1>)
# 0 314 tensor([0.8352], grad_fn=<SumBackward1>)
# 0 315 tensor([0.8388], grad_fn=<SumBackward1>)
# 0 316 tensor([0.8335], grad_fn=<SumBackward1>)
# 0 317 tensor([0.8459], grad_fn=<SumBackward1>)
# 0 318 tensor([0.8261], grad_fn=<SumBackward1>)
# 0 319 tensor([0.8217], grad_fn=<SumBackward1>)
# 0 320 tensor([0.8407], grad_fn=<SumBackward1>)
# 0 321 tensor([0.8240], grad_fn=<SumBackward1>)
# 0 322 tensor([0.8415], grad_fn=<SumBackward1>)
# 0 323 tensor([0.8270], grad_fn=<SumBackward1>)
# 0 324 tensor([0.8532], grad_fn=<SumBackward1>)
# 0 325 tensor([0.8441], grad_fn=<SumBackward1>)
# 0 326 tensor([0.8122], grad_fn=<SumBackward1>)
# 0 327 tensor([0.8277], grad_fn=<SumBackward1>)
# 0 328 tensor([0.8041], grad_fn=<SumBackward1>)
# 0 329 tensor([0.8368], grad_fn=<SumBackward1>)
# 0 330 tensor([0.8587], grad_fn=<SumBackward1>)
# 0 331 tensor([0.8224], grad_fn=<SumBackward1>)
# 0 332 tensor([0.8294], grad_fn=<SumBackward1>)
# 0 333 tensor([0.8233], grad_fn=<SumBackward1>)
# 0 334 tensor([0.8749], grad_fn=<SumBackward1>)
# 0 335 tensor([0.8596], grad_fn=<SumBackward1>)
# 0 336 tensor([0.8762], grad_fn=<SumBackward1>)
# 0 337 tensor([0.8705], grad_fn=<SumBackward1>)
# 0 338 tensor([0.8549], grad_fn=<SumBackward1>)
# 0 339 tensor([0.8362], grad_fn=<SumBackward1>)
# 0 340 tensor([0.8215], grad_fn=<SumBackward1>)
# 0 341 tensor([0.8433], grad_fn=<SumBackward1>)
# 0 342 tensor([0.8613], grad_fn=<SumBackward1>)
# 0 343 tensor([0.8434], grad_fn=<SumBackward1>)
# 0 344 tensor([0.8023], grad_fn=<SumBackward1>)
# 0 345 tensor([0.8412], grad_fn=<SumBackward1>)
# 0 346 tensor([0.7734], grad_fn=<SumBackward1>)
# 0 347 tensor([0.7747], grad_fn=<SumBackward1>)
# 0 348 tensor([0.8550], grad_fn=<SumBackward1>)
# 0 349 tensor([0.8544], grad_fn=<SumBackward1>)
# 0 350 tensor([0.8011], grad_fn=<SumBackward1>)
# 0 351 tensor([0.7974], grad_fn=<SumBackward1>)
# 0 352 tensor([0.8173], grad_fn=<SumBackward1>)
# 0 353 tensor([0.8005], grad_fn=<SumBackward1>)
# 0 354 tensor([0.8446], grad_fn=<SumBackward1>)
# 0 355 tensor([0.7870], grad_fn=<SumBackward1>)
# 0 356 tensor([0.7677], grad_fn=<SumBackward1>)
# 0 357 tensor([0.8110], grad_fn=<SumBackward1>)
# 0 358 tensor([0.7811], grad_fn=<SumBackward1>)
# 0 359 tensor([0.8335], grad_fn=<SumBackward1>)
# 0 360 tensor([0.8070], grad_fn=<SumBackward1>)
# 0 361 tensor([0.8083], grad_fn=<SumBackward1>)
# 0 362 tensor([0.8560], grad_fn=<SumBackward1>)
# 0 363 tensor([0.7790], grad_fn=<SumBackward1>)
# 0 364 tensor([0.7975], grad_fn=<SumBackward1>)
# 0 365 tensor([0.8132], grad_fn=<SumBackward1>)
# 0 366 tensor([0.8095], grad_fn=<SumBackward1>)
# 0 367 tensor([0.7817], grad_fn=<SumBackward1>)
# 0 368 tensor([0.8189], grad_fn=<SumBackward1>)
# 0 369 tensor([0.7779], grad_fn=<SumBackward1>)
# 0 370 tensor([0.7948], grad_fn=<SumBackward1>)
# 0 371 tensor([0.8261], grad_fn=<SumBackward1>)
# 0 372 tensor([0.7542], grad_fn=<SumBackward1>)
# 0 373 tensor([0.8066], grad_fn=<SumBackward1>)
# 0 374 tensor([0.8095], grad_fn=<SumBackward1>)
# 0 375 tensor([0.7821], grad_fn=<SumBackward1>)
# 0 376 tensor([0.8282], grad_fn=<SumBackward1>)
# 0 377 tensor([0.8305], grad_fn=<SumBackward1>)
# 0 378 tensor([0.8326], grad_fn=<SumBackward1>)
# 0 379 tensor([0.8040], grad_fn=<SumBackward1>)
# 0 380 tensor([0.8024], grad_fn=<SumBackward1>)
# 0 381 tensor([0.8300], grad_fn=<SumBackward1>)
# 0 382 tensor([0.8322], grad_fn=<SumBackward1>)
# 0 383 tensor([0.8513], grad_fn=<SumBackward1>)
# 0 384 tensor([0.8308], grad_fn=<SumBackward1>)
# 0 385 tensor([0.8325], grad_fn=<SumBackward1>)
# 0 386 tensor([0.8749], grad_fn=<SumBackward1>)
# 0 387 tensor([0.8588], grad_fn=<SumBackward1>)
# 0 388 tensor([0.8408], grad_fn=<SumBackward1>)
# 0 389 tensor([0.8715], grad_fn=<SumBackward1>)
# 0 390 tensor([0.8510], grad_fn=<SumBackward1>)
# 0 391 tensor([0.8245], grad_fn=<SumBackward1>)
# 0 392 tensor([0.8168], grad_fn=<SumBackward1>)
# 0 393 tensor([0.8398], grad_fn=<SumBackward1>)
# 0 394 tensor([0.8166], grad_fn=<SumBackward1>)
# 0 395 tensor([0.8457], grad_fn=<SumBackward1>)
# 0 396 tensor([0.8475], grad_fn=<SumBackward1>)
# 0 397 tensor([0.8414], grad_fn=<SumBackward1>)
# 0 398 tensor([0.8464], grad_fn=<SumBackward1>)
# 0 399 tensor([0.8536], grad_fn=<SumBackward1>)
# 0 400 tensor([0.8195], grad_fn=<SumBackward1>)
# 0 401 tensor([0.8444], grad_fn=<SumBackward1>)
# 0 402 tensor([0.8064], grad_fn=<SumBackward1>)
# 0 403 tensor([0.8281], grad_fn=<SumBackward1>)
# 0 404 tensor([0.8028], grad_fn=<SumBackward1>)
# 0 405 tensor([0.7655], grad_fn=<SumBackward1>)
# 0 406 tensor([0.7526], grad_fn=<SumBackward1>)
# 0 407 tensor([0.7623], grad_fn=<SumBackward1>)
# 0 408 tensor([0.8161], grad_fn=<SumBackward1>)
# 0 409 tensor([0.8053], grad_fn=<SumBackward1>)
# 0 410 tensor([0.8161], grad_fn=<SumBackward1>)
# 0 411 tensor([0.8276], grad_fn=<SumBackward1>)
# 0 412 tensor([0.8284], grad_fn=<SumBackward1>)
# 0 413 tensor([0.8584], grad_fn=<SumBackward1>)
# 0 414 tensor([0.8314], grad_fn=<SumBackward1>)
# 0 415 tensor([0.8507], grad_fn=<SumBackward1>)
# 0 416 tensor([0.8332], grad_fn=<SumBackward1>)
# 0 417 tensor([0.8205], grad_fn=<SumBackward1>)
# 0 418 tensor([0.7838], grad_fn=<SumBackward1>)
# 0 419 tensor([0.8045], grad_fn=<SumBackward1>)
# 0 420 tensor([0.8323], grad_fn=<SumBackward1>)
# 0 421 tensor([0.8281], grad_fn=<SumBackward1>)
# 0 422 tensor([0.8192], grad_fn=<SumBackward1>)
# 0 423 tensor([0.8247], grad_fn=<SumBackward1>)
# 0 424 tensor([0.8189], grad_fn=<SumBackward1>)
# 0 425 tensor([0.8233], grad_fn=<SumBackward1>)
# 0 426 tensor([0.8109], grad_fn=<SumBackward1>)
# 0 427 tensor([0.7898], grad_fn=<SumBackward1>)
# 0 428 tensor([0.7811], grad_fn=<SumBackward1>)
# 0 429 tensor([0.8054], grad_fn=<SumBackward1>)
# 0 430 tensor([0.7988], grad_fn=<SumBackward1>)
# 0 431 tensor([0.8241], grad_fn=<SumBackward1>)
# 0 432 tensor([0.8590], grad_fn=<SumBackward1>)
# 0 433 tensor([0.8126], grad_fn=<SumBackward1>)
# 0 434 tensor([0.8329], grad_fn=<SumBackward1>)
# 0 435 tensor([0.8104], grad_fn=<SumBackward1>)
# 0 436 tensor([0.8142], grad_fn=<SumBackward1>)
# 0 437 tensor([0.8147], grad_fn=<SumBackward1>)
# 0 438 tensor([0.8420], grad_fn=<SumBackward1>)
# 0 439 tensor([0.8790], grad_fn=<SumBackward1>)
# 0 440 tensor([0.8125], grad_fn=<SumBackward1>)
# 0 441 tensor([0.8372], grad_fn=<SumBackward1>)
# 0 442 tensor([0.7916], grad_fn=<SumBackward1>)
# 0 443 tensor([0.8071], grad_fn=<SumBackward1>)
# 0 444 tensor([0.7703], grad_fn=<SumBackward1>)
# 0 445 tensor([0.7227], grad_fn=<SumBackward1>)
# 0 446 tensor([0.6931], grad_fn=<SumBackward1>)
# 0 447 tensor([0.8300], grad_fn=<SumBackward1>)
# 0 448 tensor([0.7780], grad_fn=<SumBackward1>)
# 0 449 tensor([0.7780], grad_fn=<SumBackward1>)
# 0 450 tensor([0.8048], grad_fn=<SumBackward1>)
# 0 451 tensor([0.8216], grad_fn=<SumBackward1>)
# 0 452 tensor([0.8191], grad_fn=<SumBackward1>)
# 0 453 tensor([0.7822], grad_fn=<SumBackward1>)
# 0 454 tensor([0.8080], grad_fn=<SumBackward1>)
# 0 455 tensor([0.7769], grad_fn=<SumBackward1>)
# 0 456 tensor([0.7568], grad_fn=<SumBackward1>)
# 0 457 tensor([0.7779], grad_fn=<SumBackward1>)
# 0 458 tensor([0.7345], grad_fn=<SumBackward1>)
# 0 459 tensor([0.8169], grad_fn=<SumBackward1>)
# 0 460 tensor([0.8306], grad_fn=<SumBackward1>)
# 0 461 tensor([0.7783], grad_fn=<SumBackward1>)
# 0 462 tensor([0.8353], grad_fn=<SumBackward1>)
# 0 463 tensor([0.8685], grad_fn=<SumBackward1>)
# 0 464 tensor([0.8187], grad_fn=<SumBackward1>)
# 0 465 tensor([0.8760], grad_fn=<SumBackward1>)
# 0 466 tensor([0.7551], grad_fn=<SumBackward1>)
# 0 467 tensor([0.7769], grad_fn=<SumBackward1>)
# 0 468 tensor([0.7929], grad_fn=<SumBackward1>)
# 0 469 tensor([0.7820], grad_fn=<SumBackward1>)
# 0 470 tensor([0.7595], grad_fn=<SumBackward1>)
# 0 471 tensor([0.7482], grad_fn=<SumBackward1>)
# 0 472 tensor([0.8379], grad_fn=<SumBackward1>)
# 0 473 tensor([0.8605], grad_fn=<SumBackward1>)
# 0 474 tensor([0.8383], grad_fn=<SumBackward1>)
# 0 475 tensor([0.8685], grad_fn=<SumBackward1>)
# 0 476 tensor([0.8843], grad_fn=<SumBackward1>)
# 0 477 tensor([0.8694], grad_fn=<SumBackward1>)
# 0 478 tensor([0.8843], grad_fn=<SumBackward1>)
# 0 479 tensor([0.8647], grad_fn=<SumBackward1>)
# 0 480 tensor([0.8820], grad_fn=<SumBackward1>)
# 0 481 tensor([0.8717], grad_fn=<SumBackward1>)
# 0 482 tensor([0.8755], grad_fn=<SumBackward1>)
# 0 483 tensor([0.8665], grad_fn=<SumBackward1>)
# 0 484 tensor([0.8787], grad_fn=<SumBackward1>)
# 0 485 tensor([0.8869], grad_fn=<SumBackward1>)
# 0 486 tensor([0.8490], grad_fn=<SumBackward1>)
# 0 487 tensor([0.8577], grad_fn=<SumBackward1>)
# 0 488 tensor([0.7538], grad_fn=<SumBackward1>)
# 0 489 tensor([0.7801], grad_fn=<SumBackward1>)
# 0 490 tensor([0.7664], grad_fn=<SumBackward1>)
# 0 491 tensor([0.7289], grad_fn=<SumBackward1>)
# 0 492 tensor([0.7495], grad_fn=<SumBackward1>)
# 0 493 tensor([0.7721], grad_fn=<SumBackward1>)
# 0 494 tensor([0.8259], grad_fn=<SumBackward1>)
# 0 495 tensor([0.7552], grad_fn=<SumBackward1>)
# 0 496 tensor([0.9380], grad_fn=<SumBackward1>)
# 0 497 tensor([0.8926], grad_fn=<SumBackward1>)
# 0 498 tensor([0.9008], grad_fn=<SumBackward1>)
# 0 499 tensor([0.8812], grad_fn=<SumBackward1>)
# 0 500 tensor([0.8543], grad_fn=<SumBackward1>)
# 0 501 tensor([0.8930], grad_fn=<SumBackward1>)
# 0 502 tensor([0.8896], grad_fn=<SumBackward1>)
# 0 503 tensor([0.8788], grad_fn=<SumBackward1>)
# 0 504 tensor([0.8805], grad_fn=<SumBackward1>)
# 0 505 tensor([0.8988], grad_fn=<SumBackward1>)
# 0 506 tensor([0.8857], grad_fn=<SumBackward1>)
# 0 507 tensor([0.7956], grad_fn=<SumBackward1>)
# 0 508 tensor([0.8052], grad_fn=<SumBackward1>)
# 0 509 tensor([0.7736], grad_fn=<SumBackward1>)
# 0 510 tensor([0.7859], grad_fn=<SumBackward1>)
# 0 511 tensor([0.7653], grad_fn=<SumBackward1>)
# 0 512 tensor([0.7725], grad_fn=<SumBackward1>)
# 0 513 tensor([0.7504], grad_fn=<SumBackward1>)
# 0 514 tensor([0.7758], grad_fn=<SumBackward1>)
# 0 515 tensor([0.8509], grad_fn=<SumBackward1>)
# 0 516 tensor([0.8415], grad_fn=<SumBackward1>)
# 0 517 tensor([0.8736], grad_fn=<SumBackward1>)
# 0 518 tensor([0.9010], grad_fn=<SumBackward1>)
# 0 519 tensor([0.8758], grad_fn=<SumBackward1>)
# 0 520 tensor([0.8639], grad_fn=<SumBackward1>)
# 0 521 tensor([0.8408], grad_fn=<SumBackward1>)
# 0 522 tensor([0.8404], grad_fn=<SumBackward1>)
# 0 523 tensor([0.8265], grad_fn=<SumBackward1>)
# 0 524 tensor([0.8028], grad_fn=<SumBackward1>)
# 0 525 tensor([0.7993], grad_fn=<SumBackward1>)
# 0 526 tensor([0.8151], grad_fn=<SumBackward1>)
# 0 527 tensor([0.7943], grad_fn=<SumBackward1>)
# 0 528 tensor([0.8086], grad_fn=<SumBackward1>)
# 0 529 tensor([0.8018], grad_fn=<SumBackward1>)
# 0 530 tensor([0.7757], grad_fn=<SumBackward1>)
# 0 531 tensor([0.7509], grad_fn=<SumBackward1>)
# 0 532 tensor([0.7681], grad_fn=<SumBackward1>)
# 0 533 tensor([0.7490], grad_fn=<SumBackward1>)
# 0 534 tensor([0.7761], grad_fn=<SumBackward1>)
# 0 535 tensor([0.7985], grad_fn=<SumBackward1>)
# 0 536 tensor([0.7834], grad_fn=<SumBackward1>)
# 0 537 tensor([0.7906], grad_fn=<SumBackward1>)
# 0 538 tensor([0.8573], grad_fn=<SumBackward1>)
# 0 539 tensor([0.8545], grad_fn=<SumBackward1>)
# 0 540 tensor([0.8487], grad_fn=<SumBackward1>)
# 0 541 tensor([0.8610], grad_fn=<SumBackward1>)
# 0 542 tensor([0.8500], grad_fn=<SumBackward1>)
# 0 543 tensor([0.8406], grad_fn=<SumBackward1>)
# 0 544 tensor([0.8524], grad_fn=<SumBackward1>)
# 0 545 tensor([0.8097], grad_fn=<SumBackward1>)
# 0 546 tensor([0.8003], grad_fn=<SumBackward1>)
# 0 547 tensor([0.8261], grad_fn=<SumBackward1>)
# 0 548 tensor([0.8465], grad_fn=<SumBackward1>)
# 0 549 tensor([0.8252], grad_fn=<SumBackward1>)
# 0 550 tensor([0.8206], grad_fn=<SumBackward1>)
# 0 551 tensor([0.7985], grad_fn=<SumBackward1>)
# 0 552 tensor([0.8327], grad_fn=<SumBackward1>)
# 0 553 tensor([0.8470], grad_fn=<SumBackward1>)
# 0 554 tensor([0.8203], grad_fn=<SumBackward1>)
# 0 555 tensor([0.8409], grad_fn=<SumBackward1>)
# 0 556 tensor([0.8437], grad_fn=<SumBackward1>)
# 0 557 tensor([0.8338], grad_fn=<SumBackward1>)
# 0 558 tensor([0.8139], grad_fn=<SumBackward1>)
# 0 559 tensor([0.8575], grad_fn=<SumBackward1>)
# 0 560 tensor([0.8459], grad_fn=<SumBackward1>)
# 0 561 tensor([0.8582], grad_fn=<SumBackward1>)
# 0 562 tensor([0.8089], grad_fn=<SumBackward1>)
# 0 563 tensor([0.8300], grad_fn=<SumBackward1>)
# 0 564 tensor([0.8517], grad_fn=<SumBackward1>)
# 0 565 tensor([0.8254], grad_fn=<SumBackward1>)
# 0 566 tensor([0.8583], grad_fn=<SumBackward1>)
# 0 567 tensor([0.8726], grad_fn=<SumBackward1>)
# 0 568 tensor([0.8830], grad_fn=<SumBackward1>)
# 0 569 tensor([0.8780], grad_fn=<SumBackward1>)
# 0 570 tensor([0.8245], grad_fn=<SumBackward1>)
# 0 571 tensor([0.8295], grad_fn=<SumBackward1>)
# 0 572 tensor([0.8235], grad_fn=<SumBackward1>)
# 0 573 tensor([0.8498], grad_fn=<SumBackward1>)
# 0 574 tensor([0.8208], grad_fn=<SumBackward1>)
# 0 575 tensor([0.8516], grad_fn=<SumBackward1>)
# 0 576 tensor([0.8529], grad_fn=<SumBackward1>)
# 0 577 tensor([0.8229], grad_fn=<SumBackward1>)
# 0 578 tensor([0.8236], grad_fn=<SumBackward1>)
# 0 579 tensor([0.8749], grad_fn=<SumBackward1>)
# 0 580 tensor([0.8649], grad_fn=<SumBackward1>)
# 0 581 tensor([0.8738], grad_fn=<SumBackward1>)
# 0 582 tensor([0.8201], grad_fn=<SumBackward1>)
# 0 583 tensor([0.8157], grad_fn=<SumBackward1>)
# 0 584 tensor([0.8258], grad_fn=<SumBackward1>)
# 0 585 tensor([0.8205], grad_fn=<SumBackward1>)
# 0 586 tensor([0.8275], grad_fn=<SumBackward1>)
# 0 587 tensor([0.8266], grad_fn=<SumBackward1>)
# 0 588 tensor([0.8609], grad_fn=<SumBackward1>)
# 0 589 tensor([0.8529], grad_fn=<SumBackward1>)
# 0 590 tensor([0.8312], grad_fn=<SumBackward1>)
# 0 591 tensor([0.8445], grad_fn=<SumBackward1>)
# 0 592 tensor([0.8403], grad_fn=<SumBackward1>)
# 0 593 tensor([0.8559], grad_fn=<SumBackward1>)
# 0 594 tensor([0.8561], grad_fn=<SumBackward1>)
# 0 595 tensor([0.8258], grad_fn=<SumBackward1>)
# 0 596 tensor([0.8325], grad_fn=<SumBackward1>)
# 0 597 tensor([0.8398], grad_fn=<SumBackward1>)
# 0 598 tensor([0.8536], grad_fn=<SumBackward1>)
# 0 599 tensor([0.8596], grad_fn=<SumBackward1>)
# 0 600 tensor([0.8596], grad_fn=<SumBackward1>)
# 0 601 tensor([0.8529], grad_fn=<SumBackward1>)
# 0 602 tensor([0.8575], grad_fn=<SumBackward1>)
# 0 603 tensor([0.8544], grad_fn=<SumBackward1>)
# 0 604 tensor([0.8433], grad_fn=<SumBackward1>)
# 0 605 tensor([0.8452], grad_fn=<SumBackward1>)
# 0 606 tensor([0.8428], grad_fn=<SumBackward1>)
# 0 607 tensor([0.7515], grad_fn=<SumBackward1>)
# 0 608 tensor([0.7630], grad_fn=<SumBackward1>)
# 0 609 tensor([0.7716], grad_fn=<SumBackward1>)
# 0 610 tensor([0.7800], grad_fn=<SumBackward1>)
# 0 611 tensor([0.7530], grad_fn=<SumBackward1>)
# 0 612 tensor([0.7852], grad_fn=<SumBackward1>)
# 0 613 tensor([0.7847], grad_fn=<SumBackward1>)
# 0 614 tensor([0.7726], grad_fn=<SumBackward1>)
# 0 615 tensor([0.8019], grad_fn=<SumBackward1>)
# 0 616 tensor([0.7727], grad_fn=<SumBackward1>)
# 0 617 tensor([0.7729], grad_fn=<SumBackward1>)
# 0 618 tensor([0.7698], grad_fn=<SumBackward1>)
# 0 619 tensor([0.7893], grad_fn=<SumBackward1>)
# 0 620 tensor([0.7542], grad_fn=<SumBackward1>)
# 0 621 tensor([0.7691], grad_fn=<SumBackward1>)
# 0 622 tensor([0.8044], grad_fn=<SumBackward1>)
# 0 623 tensor([0.7794], grad_fn=<SumBackward1>)
# 0 624 tensor([0.7719], grad_fn=<SumBackward1>)
# 0 625 tensor([0.8129], grad_fn=<SumBackward1>)
# 0 626 tensor([0.7745], grad_fn=<SumBackward1>)
# 0 627 tensor([0.8001], grad_fn=<SumBackward1>)
# 0 628 tensor([0.7853], grad_fn=<SumBackward1>)
# 0 629 tensor([0.8294], grad_fn=<SumBackward1>)
# 0 630 tensor([0.8070], grad_fn=<SumBackward1>)
# 0 631 tensor([0.8207], grad_fn=<SumBackward1>)
# 0 632 tensor([0.8064], grad_fn=<SumBackward1>)
# 0 633 tensor([0.8003], grad_fn=<SumBackward1>)
# 0 634 tensor([0.8025], grad_fn=<SumBackward1>)
# 0 635 tensor([0.7927], grad_fn=<SumBackward1>)
# 0 636 tensor([0.8207], grad_fn=<SumBackward1>)
# 0 637 tensor([0.8133], grad_fn=<SumBackward1>)
# 0 638 tensor([0.7908], grad_fn=<SumBackward1>)
# 0 639 tensor([0.8072], grad_fn=<SumBackward1>)
# 0 640 tensor([0.8043], grad_fn=<SumBackward1>)
# 0 641 tensor([0.8017], grad_fn=<SumBackward1>)
# 0 642 tensor([0.8360], grad_fn=<SumBackward1>)
# 0 643 tensor([0.8028], grad_fn=<SumBackward1>)
# 0 644 tensor([0.8032], grad_fn=<SumBackward1>)
# 0 645 tensor([0.8140], grad_fn=<SumBackward1>)
# 0 646 tensor([0.8274], grad_fn=<SumBackward1>)
# 0 647 tensor([0.7845], grad_fn=<SumBackward1>)
# 0 648 tensor([0.8167], grad_fn=<SumBackward1>)
# 0 649 tensor([0.8098], grad_fn=<SumBackward1>)
# 0 650 tensor([0.8398], grad_fn=<SumBackward1>)
# 0 651 tensor([0.8138], grad_fn=<SumBackward1>)
# 0 652 tensor([0.8526], grad_fn=<SumBackward1>)
# 0 653 tensor([0.8180], grad_fn=<SumBackward1>)
# 0 654 tensor([0.8327], grad_fn=<SumBackward1>)
# 0 655 tensor([0.8340], grad_fn=<SumBackward1>)
# 0 656 tensor([0.8621], grad_fn=<SumBackward1>)
# 0 657 tensor([0.8745], grad_fn=<SumBackward1>)
# 0 658 tensor([0.8793], grad_fn=<SumBackward1>)
# 0 659 tensor([0.8258], grad_fn=<SumBackward1>)
# 0 660 tensor([0.8353], grad_fn=<SumBackward1>)
# 0 661 tensor([0.8259], grad_fn=<SumBackward1>)
# 0 662 tensor([0.8149], grad_fn=<SumBackward1>)
# 0 663 tensor([0.8224], grad_fn=<SumBackward1>)
# 0 664 tensor([0.8354], grad_fn=<SumBackward1>)
# 0 665 tensor([0.8557], grad_fn=<SumBackward1>)
# 0 666 tensor([0.8453], grad_fn=<SumBackward1>)
# 0 667 tensor([0.8632], grad_fn=<SumBackward1>)
# 0 668 tensor([0.8427], grad_fn=<SumBackward1>)
# 0 669 tensor([0.8686], grad_fn=<SumBackward1>)
# 0 670 tensor([0.8201], grad_fn=<SumBackward1>)
# 0 671 tensor([0.8833], grad_fn=<SumBackward1>)
# 0 672 tensor([0.8355], grad_fn=<SumBackward1>)
# 0 673 tensor([0.8418], grad_fn=<SumBackward1>)
# 0 674 tensor([0.8147], grad_fn=<SumBackward1>)
# 0 675 tensor([0.8531], grad_fn=<SumBackward1>)
# 0 676 tensor([0.8739], grad_fn=<SumBackward1>)
# 0 677 tensor([0.8715], grad_fn=<SumBackward1>)
# 0 678 tensor([0.8578], grad_fn=<SumBackward1>)
# 0 679 tensor([0.8126], grad_fn=<SumBackward1>)
# 0 680 tensor([0.8297], grad_fn=<SumBackward1>)
# 0 681 tensor([0.8789], grad_fn=<SumBackward1>)
# 0 682 tensor([0.8554], grad_fn=<SumBackward1>)
# 0 683 tensor([0.8607], grad_fn=<SumBackward1>)
# 0 684 tensor([0.8670], grad_fn=<SumBackward1>)
# 0 685 tensor([0.8072], grad_fn=<SumBackward1>)
# 0 686 tensor([0.8400], grad_fn=<SumBackward1>)
# 0 687 tensor([0.7935], grad_fn=<SumBackward1>)
# 0 688 tensor([0.8322], grad_fn=<SumBackward1>)
# 0 689 tensor([0.8533], grad_fn=<SumBackward1>)
# 0 690 tensor([0.8291], grad_fn=<SumBackward1>)
# 0 691 tensor([0.8652], grad_fn=<SumBackward1>)
# 0 692 tensor([0.8440], grad_fn=<SumBackward1>)
# 0 693 tensor([0.8618], grad_fn=<SumBackward1>)
# 0 694 tensor([0.8461], grad_fn=<SumBackward1>)
# 0 695 tensor([0.8561], grad_fn=<SumBackward1>)
# 0 696 tensor([0.8477], grad_fn=<SumBackward1>)
# 0 697 tensor([0.8506], grad_fn=<SumBackward1>)
# 0 698 tensor([0.8543], grad_fn=<SumBackward1>)
# 0 699 tensor([0.8564], grad_fn=<SumBackward1>)
# 0 700 tensor([0.8525], grad_fn=<SumBackward1>)
# 0 701 tensor([0.8313], grad_fn=<SumBackward1>)
# 0 702 tensor([0.8270], grad_fn=<SumBackward1>)
# 0 703 tensor([0.8325], grad_fn=<SumBackward1>)
# 0 704 tensor([0.8624], grad_fn=<SumBackward1>)
# 0 705 tensor([0.8206], grad_fn=<SumBackward1>)
# 0 706 tensor([0.8524], grad_fn=<SumBackward1>)
# 0 707 tensor([0.8302], grad_fn=<SumBackward1>)
# 0 708 tensor([0.8650], grad_fn=<SumBackward1>)
# 0 709 tensor([0.8179], grad_fn=<SumBackward1>)
# 0 710 tensor([0.8538], grad_fn=<SumBackward1>)
# 0 711 tensor([0.8452], grad_fn=<SumBackward1>)
# 0 712 tensor([0.8398], grad_fn=<SumBackward1>)
# 0 713 tensor([0.8559], grad_fn=<SumBackward1>)
# 0 714 tensor([0.8299], grad_fn=<SumBackward1>)
# 0 715 tensor([0.8388], grad_fn=<SumBackward1>)
# 0 716 tensor([0.8059], grad_fn=<SumBackward1>)
# 0 717 tensor([0.8325], grad_fn=<SumBackward1>)
# 0 718 tensor([0.8558], grad_fn=<SumBackward1>)
# 0 719 tensor([0.8281], grad_fn=<SumBackward1>)
# 0 720 tensor([0.8178], grad_fn=<SumBackward1>)
# 0 721 tensor([0.8493], grad_fn=<SumBackward1>)
# 0 722 tensor([0.8412], grad_fn=<SumBackward1>)
# 0 723 tensor([0.8438], grad_fn=<SumBackward1>)
# 0 724 tensor([0.8565], grad_fn=<SumBackward1>)
# 0 725 tensor([0.8088], grad_fn=<SumBackward1>)
# 0 726 tensor([0.8264], grad_fn=<SumBackward1>)
# 0 727 tensor([0.8131], grad_fn=<SumBackward1>)
# 0 728 tensor([0.8556], grad_fn=<SumBackward1>)
# 0 729 tensor([0.8412], grad_fn=<SumBackward1>)
# 0 730 tensor([0.8626], grad_fn=<SumBackward1>)
# 0 731 tensor([0.8634], grad_fn=<SumBackward1>)
# 0 732 tensor([0.8813], grad_fn=<SumBackward1>)
# 0 733 tensor([0.8675], grad_fn=<SumBackward1>)
# 0 734 tensor([0.8584], grad_fn=<SumBackward1>)
# 0 735 tensor([0.7335], grad_fn=<SumBackward1>)
# 0 736 tensor([0.8483], grad_fn=<SumBackward1>)
# 0 737 tensor([0.8281], grad_fn=<SumBackward1>)
# 0 738 tensor([0.8536], grad_fn=<SumBackward1>)
# 0 739 tensor([0.8181], grad_fn=<SumBackward1>)
# 0 740 tensor([0.8210], grad_fn=<SumBackward1>)
# 0 741 tensor([0.8286], grad_fn=<SumBackward1>)
# 0 742 tensor([0.8427], grad_fn=<SumBackward1>)
# 0 743 tensor([0.8210], grad_fn=<SumBackward1>)
# 0 744 tensor([0.8566], grad_fn=<SumBackward1>)
# 0 745 tensor([0.8608], grad_fn=<SumBackward1>)
# 0 746 tensor([0.8619], grad_fn=<SumBackward1>)
# 0 747 tensor([0.8463], grad_fn=<SumBackward1>)
# 0 748 tensor([0.8644], grad_fn=<SumBackward1>)
# 0 749 tensor([0.8539], grad_fn=<SumBackward1>)
# 0 750 tensor([0.8232], grad_fn=<SumBackward1>)
# 0 751 tensor([0.8596], grad_fn=<SumBackward1>)
# 0 752 tensor([0.8620], grad_fn=<SumBackward1>)
# 0 753 tensor([0.8509], grad_fn=<SumBackward1>)
# 0 754 tensor([0.8370], grad_fn=<SumBackward1>)
# 0 755 tensor([0.8294], grad_fn=<SumBackward1>)
# 0 756 tensor([0.8349], grad_fn=<SumBackward1>)
# 0 757 tensor([0.8630], grad_fn=<SumBackward1>)
# 0 758 tensor([0.8344], grad_fn=<SumBackward1>)
# 0 759 tensor([0.8372], grad_fn=<SumBackward1>)
# 0 760 tensor([0.7873], grad_fn=<SumBackward1>)
# 0 761 tensor([0.8056], grad_fn=<SumBackward1>)
# 0 762 tensor([0.8333], grad_fn=<SumBackward1>)
# 0 763 tensor([0.8213], grad_fn=<SumBackward1>)
# 0 764 tensor([0.8501], grad_fn=<SumBackward1>)
# 0 765 tensor([0.8257], grad_fn=<SumBackward1>)
# 0 766 tensor([0.8122], grad_fn=<SumBackward1>)
# 0 767 tensor([0.8580], grad_fn=<SumBackward1>)
# 0 768 tensor([0.8414], grad_fn=<SumBackward1>)
# 0 769 tensor([0.8352], grad_fn=<SumBackward1>)
# 0 770 tensor([0.8218], grad_fn=<SumBackward1>)
# 0 771 tensor([0.8176], grad_fn=<SumBackward1>)
# 0 772 tensor([0.8320], grad_fn=<SumBackward1>)
# 0 773 tensor([0.8430], grad_fn=<SumBackward1>)
# 0 774 tensor([0.8569], grad_fn=<SumBackward1>)
# 0 775 tensor([0.8462], grad_fn=<SumBackward1>)
# 0 776 tensor([0.8388], grad_fn=<SumBackward1>)
# 0 777 tensor([0.8193], grad_fn=<SumBackward1>)
# 0 778 tensor([0.8475], grad_fn=<SumBackward1>)
# 0 779 tensor([0.8210], grad_fn=<SumBackward1>)
# 0 780 tensor([0.8311], grad_fn=<SumBackward1>)
# 0 781 tensor([0.8314], grad_fn=<SumBackward1>)
# 0 782 tensor([0.8291], grad_fn=<SumBackward1>)
# 0 783 tensor([0.8405], grad_fn=<SumBackward1>)
# 0 784 tensor([0.8365], grad_fn=<SumBackward1>)
# 0 785 tensor([0.8501], grad_fn=<SumBackward1>)
# 0 786 tensor([0.8356], grad_fn=<SumBackward1>)
# 0 787 tensor([0.8013], grad_fn=<SumBackward1>)
# 0 788 tensor([0.8058], grad_fn=<SumBackward1>)
# 0 789 tensor([0.8064], grad_fn=<SumBackward1>)
# 0 790 tensor([0.8047], grad_fn=<SumBackward1>)
# 0 791 tensor([0.8175], grad_fn=<SumBackward1>)
# 0 792 tensor([0.8008], grad_fn=<SumBackward1>)
# 0 793 tensor([0.8063], grad_fn=<SumBackward1>)
# 0 794 tensor([0.8000], grad_fn=<SumBackward1>)
# 0 795 tensor([0.8102], grad_fn=<SumBackward1>)
# 0 796 tensor([0.8122], grad_fn=<SumBackward1>)
# 0 797 tensor([0.8393], grad_fn=<SumBackward1>)
# 0 798 tensor([0.8304], grad_fn=<SumBackward1>)
# 0 799 tensor([0.8437], grad_fn=<SumBackward1>)
# 0 800 tensor([0.8167], grad_fn=<SumBackward1>)
# 0 801 tensor([0.8461], grad_fn=<SumBackward1>)
# 0 802 tensor([0.8132], grad_fn=<SumBackward1>)
# 0 803 tensor([0.7851], grad_fn=<SumBackward1>)
# 0 804 tensor([0.8309], grad_fn=<SumBackward1>)
# 0 805 tensor([0.8138], grad_fn=<SumBackward1>)
# 0 806 tensor([0.8368], grad_fn=<SumBackward1>)
# 0 807 tensor([0.7938], grad_fn=<SumBackward1>)
# 0 808 tensor([0.8178], grad_fn=<SumBackward1>)
# 0 809 tensor([0.8030], grad_fn=<SumBackward1>)
# 0 810 tensor([0.8195], grad_fn=<SumBackward1>)
# 0 811 tensor([0.7835], grad_fn=<SumBackward1>)
# 0 812 tensor([0.7959], grad_fn=<SumBackward1>)
# 0 813 tensor([0.8286], grad_fn=<SumBackward1>)
# 0 814 tensor([0.8055], grad_fn=<SumBackward1>)
# 0 815 tensor([0.8213], grad_fn=<SumBackward1>)
# 0 816 tensor([0.7699], grad_fn=<SumBackward1>)
# 0 817 tensor([0.8062], grad_fn=<SumBackward1>)
# 0 818 tensor([0.7911], grad_fn=<SumBackward1>)
# 0 819 tensor([0.7786], grad_fn=<SumBackward1>)
# 0 820 tensor([0.8180], grad_fn=<SumBackward1>)
# 0 821 tensor([0.8450], grad_fn=<SumBackward1>)
# 0 822 tensor([0.8113], grad_fn=<SumBackward1>)
# 0 823 tensor([0.8310], grad_fn=<SumBackward1>)
# 0 824 tensor([0.8416], grad_fn=<SumBackward1>)
# 0 825 tensor([0.8575], grad_fn=<SumBackward1>)
# 0 826 tensor([0.7955], grad_fn=<SumBackward1>)
# 0 827 tensor([0.8510], grad_fn=<SumBackward1>)
# 0 828 tensor([0.8327], grad_fn=<SumBackward1>)
# 0 829 tensor([0.8005], grad_fn=<SumBackward1>)
# 0 830 tensor([0.7840], grad_fn=<SumBackward1>)
# 0 831 tensor([0.8439], grad_fn=<SumBackward1>)
# 0 832 tensor([0.7999], grad_fn=<SumBackward1>)
# 0 833 tensor([0.8312], grad_fn=<SumBackward1>)
# 0 834 tensor([0.8183], grad_fn=<SumBackward1>)
# 0 835 tensor([0.8182], grad_fn=<SumBackward1>)
# 0 836 tensor([0.7995], grad_fn=<SumBackward1>)
# 0 837 tensor([0.8316], grad_fn=<SumBackward1>)
# 0 838 tensor([0.8401], grad_fn=<SumBackward1>)
# 0 839 tensor([0.8142], grad_fn=<SumBackward1>)
# 0 840 tensor([0.8122], grad_fn=<SumBackward1>)
# 0 841 tensor([0.8467], grad_fn=<SumBackward1>)
# 0 842 tensor([0.8064], grad_fn=<SumBackward1>)
# 0 843 tensor([0.8379], grad_fn=<SumBackward1>)
# 0 844 tensor([0.8278], grad_fn=<SumBackward1>)
# 0 845 tensor([0.8445], grad_fn=<SumBackward1>)
# 0 846 tensor([0.7871], grad_fn=<SumBackward1>)
# 0 847 tensor([0.8230], grad_fn=<SumBackward1>)
# 0 848 tensor([0.8063], grad_fn=<SumBackward1>)
# 0 849 tensor([0.8722], grad_fn=<SumBackward1>)
# 0 850 tensor([0.8535], grad_fn=<SumBackward1>)
# 0 851 tensor([0.8185], grad_fn=<SumBackward1>)
# 0 852 tensor([0.8183], grad_fn=<SumBackward1>)
# 0 853 tensor([0.8184], grad_fn=<SumBackward1>)
# 0 854 tensor([0.8443], grad_fn=<SumBackward1>)
# 0 855 tensor([0.8031], grad_fn=<SumBackward1>)
# 0 856 tensor([0.8629], grad_fn=<SumBackward1>)
# 0 857 tensor([0.8413], grad_fn=<SumBackward1>)
# 0 858 tensor([0.8634], grad_fn=<SumBackward1>)
# 0 859 tensor([0.8859], grad_fn=<SumBackward1>)
# 0 860 tensor([0.8842], grad_fn=<SumBackward1>)
# 0 861 tensor([0.8280], grad_fn=<SumBackward1>)
# 0 862 tensor([0.8701], grad_fn=<SumBackward1>)
# 0 863 tensor([0.8342], grad_fn=<SumBackward1>)
# 0 864 tensor([0.8815], grad_fn=<SumBackward1>)
# 0 865 tensor([0.8573], grad_fn=<SumBackward1>)
# 0 866 tensor([0.8514], grad_fn=<SumBackward1>)
# 0 867 tensor([0.8351], grad_fn=<SumBackward1>)
# 0 868 tensor([0.8124], grad_fn=<SumBackward1>)
# 0 869 tensor([0.8062], grad_fn=<SumBackward1>)
# 0 870 tensor([0.8013], grad_fn=<SumBackward1>)
# 0 871 tensor([0.7916], grad_fn=<SumBackward1>)
# 0 872 tensor([0.8147], grad_fn=<SumBackward1>)
# 0 873 tensor([0.8005], grad_fn=<SumBackward1>)
# 0 874 tensor([0.7997], grad_fn=<SumBackward1>)
# 0 875 tensor([0.8085], grad_fn=<SumBackward1>)
# 0 876 tensor([0.8012], grad_fn=<SumBackward1>)
# 0 877 tensor([0.8021], grad_fn=<SumBackward1>)
# 0 878 tensor([0.8186], grad_fn=<SumBackward1>)
# 0 879 tensor([0.7982], grad_fn=<SumBackward1>)
# 0 880 tensor([0.7571], grad_fn=<SumBackward1>)
# 0 881 tensor([0.7851], grad_fn=<SumBackward1>)
# 0 882 tensor([0.7724], grad_fn=<SumBackward1>)
# 0 883 tensor([0.7865], grad_fn=<SumBackward1>)
# 0 884 tensor([0.7890], grad_fn=<SumBackward1>)
# 0 885 tensor([0.8035], grad_fn=<SumBackward1>)
# 0 886 tensor([0.7868], grad_fn=<SumBackward1>)
# 0 887 tensor([0.8561], grad_fn=<SumBackward1>)
# 0 888 tensor([0.8517], grad_fn=<SumBackward1>)
# 0 889 tensor([0.8401], grad_fn=<SumBackward1>)
# 0 890 tensor([0.8591], grad_fn=<SumBackward1>)
# 0 891 tensor([0.7662], grad_fn=<SumBackward1>)
# 0 892 tensor([0.7924], grad_fn=<SumBackward1>)
# 0 893 tensor([0.7956], grad_fn=<SumBackward1>)
# 0 894 tensor([0.8052], grad_fn=<SumBackward1>)
# 0 895 tensor([0.8284], grad_fn=<SumBackward1>)
# 0 896 tensor([0.8086], grad_fn=<SumBackward1>)
# 0 897 tensor([0.8137], grad_fn=<SumBackward1>)
# 0 898 tensor([0.7936], grad_fn=<SumBackward1>)
# 0 899 tensor([0.7794], grad_fn=<SumBackward1>)
# 0 900 tensor([0.8120], grad_fn=<SumBackward1>)
# 0 901 tensor([0.8480], grad_fn=<SumBackward1>)
# 0 902 tensor([0.8321], grad_fn=<SumBackward1>)
# 0 903 tensor([0.8522], grad_fn=<SumBackward1>)
# 0 904 tensor([0.8518], grad_fn=<SumBackward1>)
# 0 905 tensor([0.8809], grad_fn=<SumBackward1>)
# 0 906 tensor([0.8475], grad_fn=<SumBackward1>)
# 0 907 tensor([0.8434], grad_fn=<SumBackward1>)
# 0 908 tensor([0.8356], grad_fn=<SumBackward1>)
# 0 909 tensor([0.8714], grad_fn=<SumBackward1>)
# 0 910 tensor([0.8717], grad_fn=<SumBackward1>)
# 0 911 tensor([0.8540], grad_fn=<SumBackward1>)
# 0 912 tensor([0.8494], grad_fn=<SumBackward1>)
# 0 913 tensor([0.8570], grad_fn=<SumBackward1>)
# 0 914 tensor([0.8549], grad_fn=<SumBackward1>)
# 0 915 tensor([0.8577], grad_fn=<SumBackward1>)
# 0 916 tensor([0.8641], grad_fn=<SumBackward1>)
# 0 917 tensor([0.8635], grad_fn=<SumBackward1>)
# 0 918 tensor([0.8668], grad_fn=<SumBackward1>)
# 0 919 tensor([0.8817], grad_fn=<SumBackward1>)
# 0 920 tensor([0.8618], grad_fn=<SumBackward1>)
# 0 921 tensor([0.8437], grad_fn=<SumBackward1>)
# 0 922 tensor([0.6453], grad_fn=<SumBackward1>)
# 0 923 tensor([0.6776], grad_fn=<SumBackward1>)
# 0 924 tensor([0.6725], grad_fn=<SumBackward1>)
# 0 925 tensor([0.6470], grad_fn=<SumBackward1>)
# 0 926 tensor([0.6241], grad_fn=<SumBackward1>)
# 0 927 tensor([0.6198], grad_fn=<SumBackward1>)
# 0 928 tensor([0.6094], grad_fn=<SumBackward1>)
# 0 929 tensor([0.6499], grad_fn=<SumBackward1>)
# 0 930 tensor([0.6272], grad_fn=<SumBackward1>)
# 0 931 tensor([0.6509], grad_fn=<SumBackward1>)
# 0 932 tensor([0.6671], grad_fn=<SumBackward1>)
# 0 933 tensor([0.6552], grad_fn=<SumBackward1>)
# 0 934 tensor([0.6336], grad_fn=<SumBackward1>)
# 0 935 tensor([0.6762], grad_fn=<SumBackward1>)
# 0 936 tensor([0.6806], grad_fn=<SumBackward1>)
# 0 937 tensor([0.6338], grad_fn=<SumBackward1>)
# 0 938 tensor([0.6530], grad_fn=<SumBackward1>)
# 0 939 tensor([0.6435], grad_fn=<SumBackward1>)
# 0 940 tensor([0.6616], grad_fn=<SumBackward1>)
# 0 941 tensor([0.5801], grad_fn=<SumBackward1>)
# 0 942 tensor([0.5887], grad_fn=<SumBackward1>)
# 0 943 tensor([0.5512], grad_fn=<SumBackward1>)
# 0 944 tensor([0.5821], grad_fn=<SumBackward1>)
# 0 945 tensor([0.6183], grad_fn=<SumBackward1>)
# 0 946 tensor([0.6128], grad_fn=<SumBackward1>)
# 0 947 tensor([0.6256], grad_fn=<SumBackward1>)
# 0 948 tensor([0.6575], grad_fn=<SumBackward1>)
# 0 949 tensor([0.8053], grad_fn=<SumBackward1>)
# 0 950 tensor([0.7981], grad_fn=<SumBackward1>)
# 0 951 tensor([0.7803], grad_fn=<SumBackward1>)
# 0 952 tensor([0.7795], grad_fn=<SumBackward1>)
# 0 953 tensor([0.7961], grad_fn=<SumBackward1>)
# 0 954 tensor([0.7832], grad_fn=<SumBackward1>)
# 0 955 tensor([0.7449], grad_fn=<SumBackward1>)
# 0 956 tensor([0.7198], grad_fn=<SumBackward1>)
# 0 957 tensor([0.7552], grad_fn=<SumBackward1>)
# 0 958 tensor([0.7709], grad_fn=<SumBackward1>)
# 0 959 tensor([0.7802], grad_fn=<SumBackward1>)
# 0 960 tensor([0.7742], grad_fn=<SumBackward1>)
# 0 961 tensor([0.7920], grad_fn=<SumBackward1>)
# 0 962 tensor([0.8131], grad_fn=<SumBackward1>)
# 0 963 tensor([0.8205], grad_fn=<SumBackward1>)
# 0 964 tensor([0.8193], grad_fn=<SumBackward1>)
# 0 965 tensor([0.8154], grad_fn=<SumBackward1>)
# 0 966 tensor([0.7885], grad_fn=<SumBackward1>)
# 0 967 tensor([0.8017], grad_fn=<SumBackward1>)
# 0 968 tensor([0.8081], grad_fn=<SumBackward1>)
# 0 969 tensor([0.8099], grad_fn=<SumBackward1>)
# 0 970 tensor([0.8262], grad_fn=<SumBackward1>)
# 0 971 tensor([0.8152], grad_fn=<SumBackward1>)
# 0 972 tensor([0.8170], grad_fn=<SumBackward1>)
# 0 973 tensor([0.8432], grad_fn=<SumBackward1>)
# 0 974 tensor([0.8405], grad_fn=<SumBackward1>)
# 0 975 tensor([0.8436], grad_fn=<SumBackward1>)
# 0 976 tensor([0.7872], grad_fn=<SumBackward1>)
# 0 977 tensor([0.7919], grad_fn=<SumBackward1>)
# 0 978 tensor([0.8178], grad_fn=<SumBackward1>)
# 0 979 tensor([0.8491], grad_fn=<SumBackward1>)
# 0 980 tensor([0.8436], grad_fn=<SumBackward1>)
# 0 981 tensor([0.8322], grad_fn=<SumBackward1>)
# 0 982 tensor([0.8147], grad_fn=<SumBackward1>)
# 0 983 tensor([0.8087], grad_fn=<SumBackward1>)
# 0 984 tensor([0.8316], grad_fn=<SumBackward1>)
# 0 985 tensor([0.8369], grad_fn=<SumBackward1>)
# 0 986 tensor([0.8327], grad_fn=<SumBackward1>)
# 0 987 tensor([0.8161], grad_fn=<SumBackward1>)
# 0 988 tensor([0.8221], grad_fn=<SumBackward1>)
# 0 989 tensor([0.8149], grad_fn=<SumBackward1>)
# 0 990 tensor([0.8245], grad_fn=<SumBackward1>)
# 0 991 tensor([0.8233], grad_fn=<SumBackward1>)
# 0 992 tensor([0.8514], grad_fn=<SumBackward1>)
# 0 993 tensor([0.8305], grad_fn=<SumBackward1>)
# 0 994 tensor([0.8834], grad_fn=<SumBackward1>)
# 0 995 tensor([0.8861], grad_fn=<SumBackward1>)
# 0 996 tensor([0.8861], grad_fn=<SumBackward1>)
# 0 997 tensor([0.8723], grad_fn=<SumBackward1>)
# 0 998 tensor([0.8658], grad_fn=<SumBackward1>)
# 0 999 tensor([0.8645], grad_fn=<SumBackward1>)
# 0 1000 tensor([0.8440], grad_fn=<SumBackward1>)
# 0 1001 tensor([0.8577], grad_fn=<SumBackward1>)
# 0 1002 tensor([0.8353], grad_fn=<SumBackward1>)
# 0 1003 tensor([0.8430], grad_fn=<SumBackward1>)
# 0 1004 tensor([0.8590], grad_fn=<SumBackward1>)
# 0 1005 tensor([0.8784], grad_fn=<SumBackward1>)
# 0 1006 tensor([0.8679], grad_fn=<SumBackward1>)
# 0 1007 tensor([0.8476], grad_fn=<SumBackward1>)
# 0 1008 tensor([0.8433], grad_fn=<SumBackward1>)
# 0 1009 tensor([0.8479], grad_fn=<SumBackward1>)
# 0 1010 tensor([0.8569], grad_fn=<SumBackward1>)
# 0 1011 tensor([0.8746], grad_fn=<SumBackward1>)
# 0 1012 tensor([0.8468], grad_fn=<SumBackward1>)
# 0 1013 tensor([0.8619], grad_fn=<SumBackward1>)
# 0 1014 tensor([0.8429], grad_fn=<SumBackward1>)
# 0 1015 tensor([0.8564], grad_fn=<SumBackward1>)
# 0 1016 tensor([0.8708], grad_fn=<SumBackward1>)
# 0 1017 tensor([0.8634], grad_fn=<SumBackward1>)
# 0 1018 tensor([0.8851], grad_fn=<SumBackward1>)
# 0 1019 tensor([0.7833], grad_fn=<SumBackward1>)
# 0 1020 tensor([0.7804], grad_fn=<SumBackward1>)
# 0 1021 tensor([0.8529], grad_fn=<SumBackward1>)
# 0 1022 tensor([0.8240], grad_fn=<SumBackward1>)
# ...
# 1 28 tensor([0.8586], grad_fn=<SumBackward1>)
# 1 29 tensor([0.8524], grad_fn=<SumBackward1>)
# 1 30 tensor([0.8315], grad_fn=<SumBackward1>)
# 1 31 tensor([0.7920], grad_fn=<SumBackward1>)
# 1 32 tensor([0.8063], grad_fn=<SumBackward1>)
# 1 33 tensor([0.8265], grad_fn=<SumBackward1>)
# 1 34 tensor([0.8214], grad_fn=<SumBackward1>)
# 1 35 tensor([0.8530], grad_fn=<SumBackward1>)
# 1 36 tensor([0.8527], grad_fn=<SumBackward1>)
# 1 37 tensor([0.8493], grad_fn=<SumBackward1>)
# 1 38 tensor([0.8266], grad_fn=<SumBackward1>)
# 1 39 tensor([0.8127], grad_fn=<SumBackward1>)
# 1 40 tensor([0.8428], grad_fn=<SumBackward1>)
# 1 41 tensor([0.8314], grad_fn=<SumBackward1>)
# 1 42 tensor([0.8070], grad_fn=<SumBackward1>)
# 1 43 tensor([0.8318], grad_fn=<SumBackward1>)
# 1 44 tensor([0.8654], grad_fn=<SumBackward1>)
# 1 45 tensor([0.8734], grad_fn=<SumBackward1>)
# 1 46 tensor([0.8827], grad_fn=<SumBackward1>)
# 1 47 tensor([0.8986], grad_fn=<SumBackward1>)
# 1 48 tensor([0.8678], grad_fn=<SumBackward1>)
# 1 49 tensor([0.8640], grad_fn=<SumBackward1>)
# 1 50 tensor([0.8340], grad_fn=<SumBackward1>)
# 1 51 tensor([0.8368], grad_fn=<SumBackward1>)
# 1 52 tensor([0.8430], grad_fn=<SumBackward1>)
# 1 53 tensor([0.8251], grad_fn=<SumBackward1>)
# 1 54 tensor([0.8936], grad_fn=<SumBackward1>)
# 1 55 tensor([0.8550], grad_fn=<SumBackward1>)
# 1 56 tensor([0.8429], grad_fn=<SumBackward1>)
# 1 57 tensor([0.8334], grad_fn=<SumBackward1>)
# 1 58 tensor([0.8489], grad_fn=<SumBackward1>)
# 1 59 tensor([0.8652], grad_fn=<SumBackward1>)
# 1 60 tensor([0.8889], grad_fn=<SumBackward1>)
# 1 61 tensor([0.8707], grad_fn=<SumBackward1>)
# 1 62 tensor([0.8933], grad_fn=<SumBackward1>)
# 1 63 tensor([0.8635], grad_fn=<SumBackward1>)
# 1 64 tensor([0.8591], grad_fn=<SumBackward1>)
# 1 65 tensor([0.8684], grad_fn=<SumBackward1>)
# 1 66 tensor([0.8506], grad_fn=<SumBackward1>)
# 1 67 tensor([0.8193], grad_fn=<SumBackward1>)
# 1 68 tensor([0.8588], grad_fn=<SumBackward1>)
# 1 69 tensor([0.8275], grad_fn=<SumBackward1>)
# 1 70 tensor([0.8522], grad_fn=<SumBackward1>)
# 1 71 tensor([0.8685], grad_fn=<SumBackward1>)
# 1 72 tensor([0.8298], grad_fn=<SumBackward1>)
# 1 73 tensor([0.8461], grad_fn=<SumBackward1>)
# 1 74 tensor([0.8691], grad_fn=<SumBackward1>)
# 1 75 tensor([0.8832], grad_fn=<SumBackward1>)
# 1 76 tensor([0.8875], grad_fn=<SumBackward1>)
# 1 77 tensor([0.8349], grad_fn=<SumBackward1>)
# 1 78 tensor([0.8410], grad_fn=<SumBackward1>)
# 1 79 tensor([0.8263], grad_fn=<SumBackward1>)
# 1 80 tensor([0.8757], grad_fn=<SumBackward1>)
# 1 81 tensor([0.8954], grad_fn=<SumBackward1>)
# 1 82 tensor([0.8781], grad_fn=<SumBackward1>)
# 1 83 tensor([0.8726], grad_fn=<SumBackward1>)
# 1 84 tensor([0.8569], grad_fn=<SumBackward1>)
# 1 85 tensor([0.8621], grad_fn=<SumBackward1>)
# 1 86 tensor([0.8329], grad_fn=<SumBackward1>)
# 1 87 tensor([0.8319], grad_fn=<SumBackward1>)
# 1 88 tensor([0.8165], grad_fn=<SumBackward1>)
# 1 89 tensor([0.8278], grad_fn=<SumBackward1>)
# 1 90 tensor([0.8276], grad_fn=<SumBackward1>)
# 1 91 tensor([0.8421], grad_fn=<SumBackward1>)
# 1 92 tensor([0.8398], grad_fn=<SumBackward1>)
# 1 93 tensor([0.8088], grad_fn=<SumBackward1>)
# 1 94 tensor([0.8027], grad_fn=<SumBackward1>)
# 1 95 tensor([0.8329], grad_fn=<SumBackward1>)
# 1 96 tensor([0.8104], grad_fn=<SumBackward1>)
# 1 97 tensor([0.8315], grad_fn=<SumBackward1>)
# 1 98 tensor([0.8143], grad_fn=<SumBackward1>)
# 1 99 tensor([0.8222], grad_fn=<SumBackward1>)
# 1 100 tensor([0.8425], grad_fn=<SumBackward1>)
# 1 101 tensor([0.8480], grad_fn=<SumBackward1>)
# 1 102 tensor([0.8677], grad_fn=<SumBackward1>)
# 1 103 tensor([0.8733], grad_fn=<SumBackward1>)
# 1 104 tensor([0.8621], grad_fn=<SumBackward1>)
# 1 105 tensor([0.8494], grad_fn=<SumBackward1>)
# 1 106 tensor([0.8417], grad_fn=<SumBackward1>)
# 1 107 tensor([0.8712], grad_fn=<SumBackward1>)
# 1 108 tensor([0.8408], grad_fn=<SumBackward1>)
# 1 109 tensor([0.7945], grad_fn=<SumBackward1>)
# 1 110 tensor([0.8422], grad_fn=<SumBackward1>)
# 1 111 tensor([0.8420], grad_fn=<SumBackward1>)
# 1 112 tensor([0.8316], grad_fn=<SumBackward1>)
# 1 113 tensor([0.8690], grad_fn=<SumBackward1>)
# 1 114 tensor([0.8642], grad_fn=<SumBackward1>)
# 1 115 tensor([0.8614], grad_fn=<SumBackward1>)
# 1 116 tensor([0.8778], grad_fn=<SumBackward1>)
# 1 117 tensor([0.8540], grad_fn=<SumBackward1>)
# 1 118 tensor([0.8607], grad_fn=<SumBackward1>)
# 1 119 tensor([0.8850], grad_fn=<SumBackward1>)
# 1 120 tensor([0.8479], grad_fn=<SumBackward1>)
# 1 121 tensor([0.8494], grad_fn=<SumBackward1>)
# 1 122 tensor([0.8602], grad_fn=<SumBackward1>)
# 1 123 tensor([0.8642], grad_fn=<SumBackward1>)
# 1 124 tensor([0.8118], grad_fn=<SumBackward1>)
# 1 125 tensor([0.8203], grad_fn=<SumBackward1>)
# 1 126 tensor([0.8449], grad_fn=<SumBackward1>)
# 1 127 tensor([0.8168], grad_fn=<SumBackward1>)
# 1 128 tensor([0.8123], grad_fn=<SumBackward1>)
# 1 129 tensor([0.8737], grad_fn=<SumBackward1>)
# 1 130 tensor([0.8739], grad_fn=<SumBackward1>)
# 1 131 tensor([0.8778], grad_fn=<SumBackward1>)
# 1 132 tensor([0.8749], grad_fn=<SumBackward1>)
# 1 133 tensor([0.8409], grad_fn=<SumBackward1>)
# 1 134 tensor([0.8509], grad_fn=<SumBackward1>)
# 1 135 tensor([0.8657], grad_fn=<SumBackward1>)
# 1 136 tensor([0.8538], grad_fn=<SumBackward1>)
# 1 137 tensor([0.8236], grad_fn=<SumBackward1>)
# 1 138 tensor([0.8189], grad_fn=<SumBackward1>)
# 1 139 tensor([0.8455], grad_fn=<SumBackward1>)
# 1 140 tensor([0.8495], grad_fn=<SumBackward1>)
# 1 141 tensor([0.8611], grad_fn=<SumBackward1>)
# 1 142 tensor([0.8742], grad_fn=<SumBackward1>)
# 1 143 tensor([0.8741], grad_fn=<SumBackward1>)
# 1 144 tensor([0.8702], grad_fn=<SumBackward1>)
# 1 145 tensor([0.8148], grad_fn=<SumBackward1>)
# 1 146 tensor([0.8715], grad_fn=<SumBackward1>)
# 1 147 tensor([0.8815], grad_fn=<SumBackward1>)
# 1 148 tensor([0.8592], grad_fn=<SumBackward1>)
# 1 149 tensor([0.8689], grad_fn=<SumBackward1>)
# 1 150 tensor([0.8527], grad_fn=<SumBackward1>)
# 1 151 tensor([0.8290], grad_fn=<SumBackward1>)
# 1 152 tensor([0.8590], grad_fn=<SumBackward1>)
# 1 153 tensor([0.8173], grad_fn=<SumBackward1>)
# 1 154 tensor([0.8151], grad_fn=<SumBackward1>)
# 1 155 tensor([0.8329], grad_fn=<SumBackward1>)
# 1 156 tensor([0.7847], grad_fn=<SumBackward1>)
# 1 157 tensor([0.8394], grad_fn=<SumBackward1>)
# 1 158 tensor([0.8793], grad_fn=<SumBackward1>)
# 1 159 tensor([0.8458], grad_fn=<SumBackward1>)
# 1 160 tensor([0.8802], grad_fn=<SumBackward1>)
# 1 161 tensor([0.8718], grad_fn=<SumBackward1>)
# 1 162 tensor([0.8650], grad_fn=<SumBackward1>)
# 1 163 tensor([0.8407], grad_fn=<SumBackward1>)
# 1 164 tensor([0.8345], grad_fn=<SumBackward1>)
# 1 165 tensor([0.8462], grad_fn=<SumBackward1>)
# 1 166 tensor([0.8274], grad_fn=<SumBackward1>)
# 1 167 tensor([0.8110], grad_fn=<SumBackward1>)
# 1 168 tensor([0.7781], grad_fn=<SumBackward1>)
# 1 169 tensor([0.8096], grad_fn=<SumBackward1>)
# 1 170 tensor([0.8198], grad_fn=<SumBackward1>)
# 1 171 tensor([0.8597], grad_fn=<SumBackward1>)
# 1 172 tensor([0.8521], grad_fn=<SumBackward1>)
# 1 173 tensor([0.8243], grad_fn=<SumBackward1>)
# 1 174 tensor([0.8158], grad_fn=<SumBackward1>)
# 1 175 tensor([0.8249], grad_fn=<SumBackward1>)
# 1 176 tensor([0.8194], grad_fn=<SumBackward1>)
# 1 177 tensor([0.8481], grad_fn=<SumBackward1>)
# 1 178 tensor([0.8433], grad_fn=<SumBackward1>)
# 1 179 tensor([0.8470], grad_fn=<SumBackward1>)
# 1 180 tensor([0.8331], grad_fn=<SumBackward1>)
# 1 181 tensor([0.8474], grad_fn=<SumBackward1>)
# 1 182 tensor([0.8170], grad_fn=<SumBackward1>)
# 1 183 tensor([0.8079], grad_fn=<SumBackward1>)
# 1 184 tensor([0.7816], grad_fn=<SumBackward1>)
# 1 185 tensor([0.8189], grad_fn=<SumBackward1>)
# 1 186 tensor([0.8080], grad_fn=<SumBackward1>)
# 1 187 tensor([0.7948], grad_fn=<SumBackward1>)
# 1 188 tensor([0.8354], grad_fn=<SumBackward1>)
# 1 189 tensor([0.8633], grad_fn=<SumBackward1>)
# 1 190 tensor([0.8539], grad_fn=<SumBackward1>)
# 1 191 tensor([0.8807], grad_fn=<SumBackward1>)
# 1 192 tensor([0.8860], grad_fn=<SumBackward1>)
# 1 193 tensor([0.8658], grad_fn=<SumBackward1>)
# 1 194 tensor([0.8796], grad_fn=<SumBackward1>)
# 1 195 tensor([0.8282], grad_fn=<SumBackward1>)
# 1 196 tensor([0.8276], grad_fn=<SumBackward1>)
# 1 197 tensor([0.8294], grad_fn=<SumBackward1>)
# 1 198 tensor([0.8232], grad_fn=<SumBackward1>)
# 1 199 tensor([0.8166], grad_fn=<SumBackward1>)
# 1 200 tensor([0.8003], grad_fn=<SumBackward1>)
# 1 201 tensor([0.8001], grad_fn=<SumBackward1>)
# 1 202 tensor([0.7788], grad_fn=<SumBackward1>)
# 1 203 tensor([0.8002], grad_fn=<SumBackward1>)
# 1 204 tensor([0.7975], grad_fn=<SumBackward1>)
# 1 205 tensor([0.7968], grad_fn=<SumBackward1>)
# 1 206 tensor([0.7920], grad_fn=<SumBackward1>)
# 1 207 tensor([0.8230], grad_fn=<SumBackward1>)
# 1 208 tensor([0.8569], grad_fn=<SumBackward1>)
# 1 209 tensor([0.8613], grad_fn=<SumBackward1>)
# 1 210 tensor([0.8848], grad_fn=<SumBackward1>)
# 1 211 tensor([0.8834], grad_fn=<SumBackward1>)
# 1 212 tensor([0.8812], grad_fn=<SumBackward1>)
# 1 213 tensor([0.8810], grad_fn=<SumBackward1>)
# 1 214 tensor([0.8686], grad_fn=<SumBackward1>)
# 1 215 tensor([0.8248], grad_fn=<SumBackward1>)
# 1 216 tensor([0.8300], grad_fn=<SumBackward1>)
# 1 217 tensor([0.8040], grad_fn=<SumBackward1>)
# 1 218 tensor([0.8059], grad_fn=<SumBackward1>)
# 1 219 tensor([0.8147], grad_fn=<SumBackward1>)
# 1 220 tensor([0.8238], grad_fn=<SumBackward1>)
# 1 221 tensor([0.8416], grad_fn=<SumBackward1>)
# 1 222 tensor([0.8421], grad_fn=<SumBackward1>)
# 1 223 tensor([0.8812], grad_fn=<SumBackward1>)
# 1 224 tensor([0.8575], grad_fn=<SumBackward1>)
# 1 225 tensor([0.8795], grad_fn=<SumBackward1>)
# 1 226 tensor([0.8899], grad_fn=<SumBackward1>)
# 1 227 tensor([0.8115], grad_fn=<SumBackward1>)
# 1 228 tensor([0.8178], grad_fn=<SumBackward1>)
# 1 229 tensor([0.7958], grad_fn=<SumBackward1>)
# 1 230 tensor([0.8070], grad_fn=<SumBackward1>)
# 1 231 tensor([0.7981], grad_fn=<SumBackward1>)
# 1 232 tensor([0.8311], grad_fn=<SumBackward1>)
# 1 233 tensor([0.8331], grad_fn=<SumBackward1>)
# 1 234 tensor([0.8587], grad_fn=<SumBackward1>)
# 1 235 tensor([0.8523], grad_fn=<SumBackward1>)
# 1 236 tensor([0.8346], grad_fn=<SumBackward1>)
# 1 237 tensor([0.8656], grad_fn=<SumBackward1>)
# 1 238 tensor([0.8612], grad_fn=<SumBackward1>)
# 1 239 tensor([0.8398], grad_fn=<SumBackward1>)
# 1 240 tensor([0.8340], grad_fn=<SumBackward1>)
# 1 241 tensor([0.8100], grad_fn=<SumBackward1>)
# 1 242 tensor([0.8067], grad_fn=<SumBackward1>)
# 1 243 tensor([0.8592], grad_fn=<SumBackward1>)
# 1 244 tensor([0.8504], grad_fn=<SumBackward1>)
# 1 245 tensor([0.8363], grad_fn=<SumBackward1>)
# 1 246 tensor([0.8283], grad_fn=<SumBackward1>)
# 1 247 tensor([0.8613], grad_fn=<SumBackward1>)
# 1 248 tensor([0.8796], grad_fn=<SumBackward1>)
# 1 249 tensor([0.8784], grad_fn=<SumBackward1>)
# 1 250 tensor([0.8315], grad_fn=<SumBackward1>)
# 1 251 tensor([0.8531], grad_fn=<SumBackward1>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 7
#       4 image1 = encode_image(file1)
#       6 for j, file2 in enumerate(path.iterdir()):
# ----> 7     image2 = encode_image(file2)
#       9     print(i, j, cosine_similarity(image1, image2))
#
# Cell In[43], line 4, in encode_image(file)
#       2 image = PIL.Image.open(file)#.unsqeeze(0)
#       3 image = pipeline(image).unsqueeze(0)
# ----> 4 embedding = embedding_model(image).flatten()
#       6 return embedding
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torchvision/models/resnet.py:94, in BasicBlock.forward(self, x)
#      92 out = self.conv1(x)
#      93 out = self.bn1(out)
# ---> 94 out = self.relu(out)
#      96 out = self.conv2(out)
#      97 out = self.bn2(out)
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/modules/activation.py:133, in ReLU.forward(self, input)
#     132 def forward(self, input: Tensor) -> Tensor:
# --> 133     return F.relu(input, inplace=self.inplace)
#
# File ~/.venvs/ai/lib64/python3.11/site-packages/torch/nn/functional.py:1702, in relu(input, inplace)
#    1700     return handle_torch_function(relu, (input,), input, inplace=inplace)
#    1701 if inplace:
# -> 1702     result = torch.relu_(input)
#    1703 else:
#    1704     result = torch.relu(input)
#
# KeyboardInterrupt:
